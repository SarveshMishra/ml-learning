# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2364, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2362     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2363 with self.builtin_trap:
# -> 2364     result = fn(*args, **kwargs)
#    2365 return result
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/magics/pylab.py:99, in PylabMagics.matplotlib(self, line)
#      97     print("Available matplotlib backends: %s" % backends_list)
#      98 else:
# ---> 99     gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
# ...

# %% [markdown]
# plt.plot();
# plt.show()

# %%
x = [1, 3, 5, 5]
y = [4, 5, 3, 7]
plt.plot(x, y)
